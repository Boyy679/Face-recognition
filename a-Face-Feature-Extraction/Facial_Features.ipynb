# %% [markdown]
# # Find facial features in picture

# %%
from IPython.display import Image, display
import face_recognition

picFile = "C:/Users/think/Desktop/Face-recognition/Source_data/biden.jpg"

# Load the jpg file into a numpy array
image = face_recognition.load_image_file(picFile)
Image(filename=picFile)

# %% [markdown]
# # Process and output

# %%
from PIL import Image, ImageDraw

# Find all facial features in all the faces in the image
face_landmarks_list = face_recognition.face_landmarks(image)

print("Found {} face in this photograph.".format(len(face_landmarks_list)))

# Create a PIL imagedraw object so we can draw on the picture
pil_image = Image.fromarray(image)
d = ImageDraw.Draw(pil_image)

for face_landmarks in face_landmarks_list:

    # Print the location of each facial feature in this image
    for facial_feature in face_landmarks.keys():
        print("The {} in this face has the points: {}".format(facial_feature, face_landmarks[facial_feature]))

    # Let's trace out each facial feature in the image with a line!
    for facial_feature in face_landmarks.keys():
        d.line(face_landmarks[facial_feature], width=5)

# Show the picture
display(pil_image)
# Out:
# Found 1 face in this photograph.
# The chin in this face has the points: [(304, 844), (313, 929), (330, 1010), (348, 1092), (376, 1169), (420, 1236), (480, 1293), (553, 1339), (636, 1350), (719, 1338), (791, 1297), (853, 1243), (898, 1177), (925, 1099), (942, 1015), (957, 931), (966, 841)]
# The left_eyebrow in this face has the points: [(350, 751), (388, 716), (442, 702), (498, 706), (551, 727)]
# The right_eyebrow in this face has the points: [(674, 721), (731, 700), (792, 696), (851, 711), (896, 747)]
# The nose_bridge in this face has the points: [(616, 812), (617, 873), (618, 933), (620, 993)]
# The nose_tip in this face has the points: [(567, 1038), (593, 1048), (622, 1056), (651, 1047), (679, 1038)]
# The left_eye in this face has the points: [(415, 822), (451, 797), (496, 801), (534, 839), (492, 843), (447, 840)]
# The right_eye in this face has the points: [(711, 838), (748, 800), (794, 797), (832, 823), (797, 840), (752, 843)]
# The top_lip in this face has the points: [(502, 1148), (553, 1128), (597, 1115), (629, 1123), (660, 1114), (706, 1127), (756, 1145), (735, 1147), (661, 1149), (629, 1152), (597, 1149), (525, 1150)]
# The bottom_lip in this face has the points: [(756, 1145), (708, 1180), (664, 1194), (629, 1197), (595, 1194), (551, 1183), (502, 1148), (525, 1150), (596, 1148), (629, 1151), (661, 1148), (735, 1147)]
# <PIL.Image.Image image mode=RGB size=1257x1880 at 0x173FF710358>
